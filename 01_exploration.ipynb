# %% [markdown]
# # ClosePrice Analysis
# ![ClosePrice](/Users/daisyzhang/IDX_ds/01_ClosePrice_Distribution.png)
# count    5.702800e+04
# mean     9.836018e+05
# std      5.231253e+05
# min      1.750000e+00
# 25%      6.000000e+05
# 50%      8.500000e+05
# 75%      1.270000e+06
# max      2.631888e+06
# Name: ClosePrice, dtype: float64
# # LivingArea Analysis
# ![LivingArea](/Users/daisyzhang/IDX_ds/01_LivingArea_Distribution.png)
# count    59216.000000
# mean      1916.844542
# std        721.773611
# min          0.000000
# 25%       1369.000000
# 50%       1787.000000
# 75%       2357.000000
# max       4058.000000
# Name: LivingArea, dtype: float64
# # BedroomsTotal Analysis
# ![BedroomsTotal](/Users/daisyzhang/IDX_ds/01_BedroomsTotal_Distribution.png)
# count    59861.000000
# mean         3.445883
# std          0.837138
# min          2.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max          5.000000
# Name: BedroomsTotal, dtype: float64
# # BathroomsTotalInteger Analysis
# ![BathroomsTotalInteger](/Users/daisyzhang/IDX_ds/01_BathroomsTotalInteger_Distribution.png)
# count    57875.000000
# mean         2.444562
# std          0.788837
# min          1.000000
# 25%          2.000000
# 50%          2.000000
# 75%          3.000000
# max          4.000000
# Name: BathroomsTotalInteger, dtype: float64
# # LotSizeSquareFeet Analysis
# ![LotSizeSquareFeet](/Users/daisyzhang/IDX_ds/01_LotSizeSquareFeet_Distribution.png)
# count    52212.000000
# mean      7231.839902
# std       2949.598597
# min          0.000000
# 25%       5400.000000
# 50%       6818.000000
# 75%       8470.000000
# max      17640.000000
# Name: LotSizeSquareFeet, dtype: float64
