# %% [markdown]
# # Results of Processsing
#   202502: removed 1622 outlier rows (8306 -> 6684)
# Processed 202502: 6684 rows
#   202503: removed 1961 outlier rows (10078 -> 8117)
# Processed 202503: 8117 rows
#   202504: removed 2140 outlier rows (11170 -> 9030)
# Processed 202504: 9030 rows
#   202505: removed 2107 outlier rows (11101 -> 8994)
# Processed 202505: 8994 rows
#   202506: removed 2132 outlier rows (11010 -> 8878)
# Processed 202506: 8878 rows
#   202507: removed 2208 outlier rows (11407 -> 9199)
# Processed 202507: 9199 rows
#   202508: removed 2088 outlier rows (10776 -> 8688)
# Processed 202508: 8688 rows
#   202509: removed 2029 outlier rows (10770 -> 8741)
# Processed 202509: 8741 rows
#   202510: removed 2260 outlier rows (11358 -> 9098)
# Processed 202510: 9098 rows
#   202511: removed 1799 outlier rows (9191 -> 7392)
# Processed 202511: 7392 rows
#   202512: removed 1986 outlier rows (9889 -> 7903)
# Processed 202512: 7903 rows
#   202601: removed 1481 outlier rows (7022 -> 5541)
# Processed 202601: 5541 rows
#   202602: removed 1589 outlier rows (8065 -> 6476)
# Processed 202602: 6476 rows
#   202603: removed 2075 outlier rows (10590 -> 8515)
# Processed 202603: 8515 rows
#   202604: removed 2170 outlier rows (11363 -> 9193)
# Processed 202604: 9193 rows
#   202605: removed 2191 outlier rows (11339 -> 9148)
# Processed 202605: 9148 rows
#
# Training on months: ['202604'], Testing on month: 202605
#   train_size=9193  RMSE=$389,091  MAE=$287,456  MAPE=36.50%
#
# Training on months: ['202603', '202604'], Testing on month: 202605
#   train_size=17708  RMSE=$385,291  MAE=$284,852  MAPE=36.17%
#
# Training on months: ['202602', '202603', '202604'], Testing on month: 202605
#   train_size=24184  RMSE=$383,373  MAE=$283,500  MAPE=35.93%
#
# Training on months: ['202511', '202512', '202601', '202602', '202603', '202604'], Testing on month: 202605
#   train_size=45020  RMSE=$382,826  MAE=$281,352  MAPE=34.82%
#
# Training on months: ['202508', '202509', '202510', '202511', '202512', '202601', '202602', '202603', '202604'], Testing on month: 202605
#   train_size=71547  RMSE=$382,007  MAE=$279,972  MAPE=34.48%
#
# Training on months: ['202505', '202506', '202507', '202508', '202509', '202510', '202511', '202512', '202601', '202602', '202603', '202604'], Testing on month: 202605
#   train_size=98618  RMSE=$379,035  MAE=$279,244  MAPE=34.83%
#
# === Summary across window lengths ===
#    window_months  train_size           rmse            mae       mape
# 0              1        9193  389090.525752  287455.742349  36.499219
# 1              2       17708  385291.254411  284851.708684  36.168159
# 2              3       24184  383373.419930  283499.528450  35.934797
# 3              6       45020  382826.374013  281351.866546  34.817149
# 4              9       71547  382007.457066  279971.580925  34.482356
# 5             12       98618  379035.314389  279243.698950  34.830673
#
# **Best window length by RMSE: X=12 months**
#
# Top 20 feature importances (from last model trained):
# LivingArea               0.408780
# YearBuilt                0.222269
# BathroomsTotalInteger    0.078616
# LotSizeSquareFeet        0.055024
# FireplaceYN              0.014332
# GarageSpaces             0.013879
# BedroomsTotal            0.006677
# zip_95124                0.006162
# zip_94539                0.005834
# zip_92677                0.005806
# zip_90266                0.004347
# zip_92024                0.004300
# zip_92694                0.004175
# zip_92651                0.004118
# zip_92618                0.003781
# zip_95120                0.003759
# zip_95051                0.003674
# zip_92127                0.003602
# zip_94582                0.003563
# zip_95125                0.003514
# dtype: float64
# ![Window Comparison](/Users/daisyzhang/IDX_ds/window_comparison.png)
