# %% [markdown]
# # Results
# Training on months: ['202505', '202506', '202507', '202508', '202509', '202510', '202511', '202512', '202601', '202602', '202603', '202604']
# Testing on month: 202605
#
# === Baseline: Linear Regression ===
#   train_size=98618  RMSE=$199,887  MAE=$136,339  R²=0.856
# Saved to baseline_linear_regression_results.csv
# (.venv) daisyzhang@Daisys-MacBook-Air IDX_ds %

# %% [markdown]
# === Baseline: Linear Regression ===
#   train_size=98618  RMSE=$199,887  MAE=$136,339  R²=0.856
# Saved to baseline_linear_regression_results.csv
#
# Top 20 features by |coefficient| (Linear Regression):
# zip_94618-1112    1.653010e+06
# zip_94539-4650    1.635089e+06
# zip_94306         1.622509e+06
# zip_94087         1.580097e+06
# zip_95014         1.578049e+06
# zip_94301         1.452635e+06
# zip_94705-2613    1.424500e+06
# zip_94027         1.421500e+06
# zip_94702-1324    1.420863e+06
# zip_90266         1.398134e+06
# zip_94040         1.388564e+06
# zip_92625         1.375062e+06
# zip_93109         1.351767e+06
# zip_92661         1.344140e+06
# zip_95129-2028    1.342403e+06
# zip_94114         1.327015e+06
# zip_94041         1.319103e+06
# zip_92663         1.318334e+06
# zip_95030         1.314160e+06
# zip_93663         1.303308e+06
# dtype: float64
# Saved to baseline_linear_regression_coefficients.csv
